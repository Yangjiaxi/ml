# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
data_ori = pd.read_csv("car.csv")

# %%
Counter(data_ori.iloc[:, -1])
# Out:
# Counter({'acc': 384, 'good': 69, 'unacc': 1210, 'vgood': 65})

# %%
def stratified(data, ratio=0.3):
    sorts = list(set(data_ori.iloc[:, -1]))
    res = pd.DataFrame()
    for sort in sorts:
        idx = (data.iloc[:, -1] == sort)
        i_sort = data[idx]
        i_len = idx.sum()
        i_target = i_len * ratio
        get = i_sort.iloc[np.random.choice(i_len, int(i_len * ratio), replace=False)]
        # print(i_len, get.shape[0])
        res = pd.concat([res, get], ignore_index=True)
    return res

stratified(data_ori)
# Out:
#     buying  maint  doors persons lug_boot safety class_values
# 0      med  vhigh      4       4    small    low        unacc
# 1     high    med      4    more      big    low        unacc
# 2      med    med      3    more    small    low        unacc
# 3     high    med      4       2    small   high        unacc
# 4      med   high      2       2      big    med        unacc
# 5      med    med      2       2      big    med        unacc
# 6      med    med  5more       4      big    low        unacc
# 7      med   high  5more       2    small    low        unacc
# 8    vhigh   high      4       2      med    med        unacc
# 9     high   high      4       2    small    low        unacc
# 10    high    med  5more       2      big   high        unacc
# 11    high    low  5more       4    small    low        unacc
# 12    high  vhigh  5more       2      med   high        unacc
# 13   vhigh   high  5more       2      big   high        unacc
# 14     low    low      2       2      med    low        unacc
# 15   vhigh  vhigh      3       2      big   high        unacc
# 16     med    med  5more       2    small    low        unacc
# 17   vhigh   high      2       2      med    low        unacc
# 18     med    med      4       4      big    low        unacc
# 19     med  vhigh      2    more    small    low        unacc
# 20    high  vhigh      4       2      big    med        unacc
# 21     med   high  5more       2      med    low        unacc
# 22     med    low      2       2    small   high        unacc
# 23     low   high      2    more    small    med        unacc
# 24   vhigh  vhigh      2       2      big    med        unacc
# 25    high   high      3       4      big    low        unacc
# 26   vhigh    low      3       2    small    med        unacc
# 27    high  vhigh      4    more    small    med        unacc
# 28    high  vhigh      4    more      big   high        unacc
# 29   vhigh    low      3       2      med    med        unacc
# ..     ...    ...    ...     ...      ...    ...          ...
# 487    low  vhigh      2    more      med   high          acc
# 488    low   high      2       4      med   high          acc
# 489   high    med      4       4    small   high          acc
# 490    med   high      2       4    small   high          acc
# 491   high   high  5more       4      med   high          acc
# 492  vhigh    low      3       4      big   high          acc
# 493    low   high      2       4      big    med          acc
# 494    low   high  5more    more      med    med          acc
# 495    low  vhigh      3    more      big   high          acc
# 496   high   high  5more       4      med    med          acc
# 497   high    med      4    more    small   high          acc
# 498    low   high      2    more      big   high        vgood
# 499    low   high      4    more      med   high        vgood
# 500    low    med      4    more      med   high        vgood
# 501    low   high      4    more      big   high        vgood
# 502    low   high  5more    more      big   high        vgood
# 503    med    med  5more    more      med   high        vgood
# 504    med    med      4    more      med   high        vgood
# 505    med    low      4       4      big   high        vgood
# 506    low    med      2    more      big   high        vgood
# 507    med    low      4    more      big   high        vgood
# 508    low    low      4    more      med   high        vgood
# 509    med    med      3    more      big   high        vgood
# 510    med    low      3    more      med   high        vgood
# 511    low    low  5more       4      med   high        vgood
# 512    low   high  5more    more      med   high        vgood
# 513    low    low      3       4      big   high        vgood
# 514    low    low      3    more      med   high        vgood
# 515    low    med      3    more      med   high        vgood
# 516    low    low      2    more      big   high        vgood
#
# [517 rows x 7 columns]

# %%
s = data_ori[data_ori.iloc[:, -1] == 'acc']
l = (data_ori.iloc[:, -1] == 'acc').sum()

# %%
s.iloc[np.random.choice(l, int(l*0.3), replace=False)]
# Out:
#      buying  maint  doors persons lug_boot safety class_values
# 425   vhigh    low  5more    more    small   high          acc
# 1070    med   high  5more       4      big   high          acc
# 1279    med    low  5more       4    small    med          acc
# 997     med   high      2    more      big    med          acc
# 1073    med   high  5more    more    small   high          acc
# 605    high   high      4       4    small   high          acc
# 403   vhigh    low      4    more      big    med          acc
# 832    high    low      4    more      med    med          acc
# 1501    low   high  5more       4      big    med          acc
# 700    high    med      3    more      big    med          acc
# 1483    low   high      4    more      big    med          acc
# 1441    low   high      3       4    small    med          acc
# 607    high   high      4       4      med    med          acc
# 616    high   high      4    more      med    med          acc
# 1046    med   high      4    more    small   high          acc
# 371   vhigh    low      3    more    small   high          acc
# 695    high    med      3    more    small   high          acc
# 986     med   high      2       4      med   high          acc
# 1015    med   high      3       4      big    med          acc
# 1334    low  vhigh      3       4    small   high          acc
# 1585    low    med      4    more    small    med          acc
# 1048    med   high      4    more      med    med          acc
# 1186    med    med  5more    more      big    med          acc
# 962     med  vhigh  5more       4      big   high          acc
# 1390    low  vhigh  5more       4      med    med          acc
# 268   vhigh    med      3    more      big    med          acc
# 431   vhigh    low  5more    more      big   high          acc
# 1049    med   high      4    more      med   high          acc
# 781    high    low      2    more      big    med          acc
# 422   vhigh    low  5more       4      big   high          acc
# ...     ...    ...    ...     ...      ...    ...          ...
# 1510    low   high  5more    more      big    med          acc
# 970     med  vhigh  5more    more      big    med          acc
# 1477    low   high      4    more    small    med          acc
# 1414    low   high      2       4    small    med          acc
# 673    high    med      2    more      big    med          acc
# 430   vhigh    low  5more    more      big    med          acc
# 809    high    low      3    more      big   high          acc
# 752    high    med  5more    more      med   high          acc
# 1549    low    med      3       4    small    med          acc
# 863    high    low  5more    more      big   high          acc
# 260   vhigh    med      3       4      big   high          acc
# 554    high   high      2       4      med   high          acc
# 1415    low   high      2       4    small   high          acc
# 421   vhigh    low  5more       4      big    med          acc
# 1495    low   high  5more       4    small    med          acc
# 958     med  vhigh  5more       4      med    med          acc
# 259   vhigh    med      3       4      big    med          acc
# 662    high    med      2       4      med   high          acc
# 1339    low  vhigh      3       4      big    med          acc
# 1117    med    med      3       4    small    med          acc
# 746    high    med  5more       4      big   high          acc
# 1118    med    med      3       4    small   high          acc
# 754    high    med  5more    more      big    med          acc
# 713    high    med      4       4    small   high          acc
# 592    high   high      3    more      big    med          acc
# 1321    low  vhigh      2    more      big    med          acc
# 698    high    med      3    more      med   high          acc
# 727    high    med      4    more      big    med          acc
# 583    high   high      3       4      big    med          acc
# 724    high    med      4    more      med    med          acc
#
# [115 rows x 7 columns]
